# %%
from search import search_movies
from poster import show_movie_poster
from history import print_log_history
import front

if __name__ == "__main__":
    while input('Search movies? (y/n): ').lower() == 'y':
        front.print_results(search_movies())

    if input("Show movie poster? (y/n):  ").lower() == 'y':
        show_movie_poster()

    if input("Show search history? (y/n): ").lower() == 'y':
        print_log_history()

    print("Enjoy watching!")
# Out:
# Search movies? (y/n):  y
# Enter genre [Action, Drama, Comedy, etc.] (or leave blank): Comedy
# Enter year [2007 - 2015] (or leave blank): 2010
# Enter an actor (or leave blank):
# Enter a minimum rating (or leave the field blank):
# ВEnter keywords (or leave blank): city
# ✅ Request recorded.
# Search results:
# +------+--------------------------+--------+----------+--------------------------------+-----------+
# |      | Title                    |   Year |   Rating | Genres                         |   Runtime |
# +======+==========================+========+==========+================================+===========+
# |  607 | Sound of Noise           |   2010 |      7.3 | ["Comedy", "Crime", "Music"]   |       102 |
# +------+--------------------------+--------+----------+--------------------------------+-----------+
# |  217 | Please Give              |   2010 |      6.6 | ["Comedy", "Drama"]            |        90 |
# ...
