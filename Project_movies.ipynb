# %%
from search import search_movies
from poster import show_movie_poster
from history import print_log_history
import front

if __name__ == "__main__":
    while input('Искать фильмы? (y/n): ').lower() == 'y':
        front.print_results(search_movies())

    if input("Показать постер к фильму? (y/n): ").lower() == 'y':
        show_movie_poster()

    if input("Показать историю запросов? (y/n): ").lower() == 'y':
        print_log_history()

    print("Приятного просмотра!")
# Out:
# Искать фильмы? (y/n):  y
# Введите жанр [Action, Drama, Comedy и т.д.] (или оставьте поле пустым): Comedy
# Введите год [2007 - 2015] (или оставьте поле пустым): 2010
# Введите актера (или оставьте поле пустым):
# Введите минимальный рейтинг (или оставьте поле пустым):
# Введите ключевые слова (или оставьте поле пустым) city
# ✅ Запрос записан.
# Результаты поиска:
# +------+--------------------------+--------+----------+--------------------------------+-----------+
# |      | Title                    |   Year |   Rating | Genres                         |   Runtime |
# +======+==========================+========+==========+================================+===========+
# |  607 | Sound of Noise           |   2010 |      7.3 | ["Comedy", "Crime", "Music"]   |       102 |
# +------+--------------------------+--------+----------+--------------------------------+-----------+
# |  217 | Please Give              |   2010 |      6.6 | ["Comedy", "Drama"]            |        90 |
# ...
